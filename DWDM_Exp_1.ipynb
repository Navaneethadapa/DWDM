# %% [markdown]
# <a href="https://colab.research.google.com/github/Navaneethadapa/DWDM/blob/main/DWDM_Exp_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Experiment 1

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# **Loading the dataset**

# %%
data = pd.read_csv("/content/train_and_test2.csv")

# %%
data
# Out:
#       Passengerid   Age      Fare  Sex  sibsp  zero  zero.1  zero.2  zero.3  \
# 0               1  22.0    7.2500    0      1     0       0       0       0
# 1               2  38.0   71.2833    1      1     0       0       0       0
# 2               3  26.0    7.9250    1      0     0       0       0       0
# 3               4  35.0   53.1000    1      1     0       0       0       0
# 4               5  35.0    8.0500    0      0     0       0       0       0
# ...           ...   ...       ...  ...    ...   ...     ...     ...     ...
# 1304         1305  28.0    8.0500    0      0     0       0       0       0
# 1305         1306  39.0  108.9000    1      0     0       0       0       0
# 1306         1307  38.5    7.2500    0      0     0       0       0       0
# 1307         1308  28.0    8.0500    0      0     0       0       0       0
# 1308         1309  28.0   22.3583    0      1     0       0       0       0
#
# ...

# %% [markdown]
# **Identifying the dependent and independent variables**

# %%
X = data.iloc[:,[2,3]] 
X
# Out:
#           Fare  Sex
# 0       7.2500    0
# 1      71.2833    1
# 2       7.9250    1
# 3      53.1000    1
# 4       8.0500    0
# ...        ...  ...
# 1304    8.0500    0
# 1305  108.9000    1
# 1306    7.2500    0
# 1307    8.0500    0
# 1308   22.3583    0
#
# [1309 rows x 2 columns]

# %%
Y = data.iloc[:,-1] 
Y
# Out:
# 0       0
# 1       1
# 2       1
# 3       1
# 4       0
#        ..
# 1304    0
# 1305    0
# 1306    0
# 1307    0
# 1308    0
# Name: 2urvived, Length: 1309, dtype: int64

# %% [markdown]
# **Dealing with missing data**

# %%
m=data['Fare'].mean() 
m1=data['Age'].median() 
data['Age'] = data['Age'].fillna (m1)
data['Fare']=data['Fare'].fillna(m) 
data
# Out:
#       Passengerid   Age      Fare  Sex  sibsp  zero  zero.1  zero.2  zero.3  \
# 0               1  22.0    7.2500    0      1     0       0       0       0
# 1               2  38.0   71.2833    1      1     0       0       0       0
# 2               3  26.0    7.9250    1      0     0       0       0       0
# 3               4  35.0   53.1000    1      1     0       0       0       0
# 4               5  35.0    8.0500    0      0     0       0       0       0
# ...           ...   ...       ...  ...    ...   ...     ...     ...     ...
# 1304         1305  28.0    8.0500    0      0     0       0       0       0
# 1305         1306  39.0  108.9000    1      0     0       0       0       0
# 1306         1307  38.5    7.2500    0      0     0       0       0       0
# 1307         1308  28.0    8.0500    0      0     0       0       0       0
# 1308         1309  28.0   22.3583    0      1     0       0       0       0
#
# ...
